# %%
pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
# Show all rows and columns without truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# importing dataframes

# %%
bacteria_path = 'https://raw.githubusercontent.com/HackBio-Internship/2025_project_collection/refs/heads/main/bacteria.csv'

# %%
bacteria_data = pd.read_csv(bacteria_path)

# %%
print(bacteria_data.head(5))
# Out:
#          C1        C2 sample_id           species Isolation origin  \
# 0  7.895415  6.303232      A001  Escherichia coli            urine
# 1  2.833671  6.823800      A002  Escherichia coli            blood
# 2  3.178256  5.519982      A003  Escherichia coli            blood
# 3  5.030077  4.642758      A004  Escherichia coli            feces
# 4  2.691040  4.057780      A005  Escherichia coli            feces
#
#            Phenotype  BSL      soln  carb_fit  cipro_fit  genta_fit   kan_fit  \
# 0  Pathogenic strain    2  0.043922  0.833539   0.040470   0.429654  0.046829
# 1  Pathogenic strain    2  0.098481  0.964883   0.110471   0.233285  0.000000
# 2   Commensal strain    1  0.066501  0.498872   0.061445   0.564547  0.313546
# 3  Pathogenic strain    2  0.116999  1.080682   0.101199   0.655379  0.305054
# 4   Commensal strain    1  0.101523  0.272807   0.120601   0.186437  0.121745
#
#     pip_fit  labels
# 0  0.857467       1
# 1  1.403835       6
# 2  0.368546       8
# ...

# %%
# Part 1: Basic Data Inspection
# Shape of the dataset
print('Shape:', bacteria_data.shape)

# List of all column names
print('Columns:', bacteria_data.columns.tolist())
# Out:
# Shape: (50, 14)
# Columns: ['C1', 'C2', 'sample_id', 'species', 'Isolation origin', 'Phenotype', 'BSL', 'soln', 'carb_fit', 'cipro_fit', 'genta_fit', 'kan_fit', 'pip_fit', 'labels']

# %%
# Part 2: Data Selection
# Select row 15
print('Select row 15:')
print(bacteria_data.iloc[[15]])

# Select the column species
print('\nSelect the column species:')
print(bacteria_data[['species']])

# Retrieve the value at row 15 for the column Isolation origin
print('\nRetrieve the value at row 15 for the column Isolation origin')
print(bacteria_data.iloc[[15]][['Isolation origin']])
# Out:
# Select row 15:
#           C1        C2 sample_id           species Isolation origin  \
# 15  7.538784  6.070635      A016  Escherichia coli            urine
#
#             Phenotype  BSL     soln  carb_fit  cipro_fit  genta_fit   kan_fit  \
# 15  Pathogenic strain    2  0.07272   0.93776   0.068781   0.423892  0.047651
#
#      pip_fit  labels
# 15  0.923642       1
#
# Select the column species:
#              species
# 0   Escherichia coli
# 1   Escherichia coli
# 2   Escherichia coli
# 3   Escherichia coli
# 4   Escherichia coli
# 5   Escherichia coli
# 6   Escherichia coli
# 7   Escherichia coli
# 8   Escherichia coli
# 9   Escherichia coli
# 10  Escherichia coli
# 11  Escherichia coli
# 12  Escherichia coli
# 13  Escherichia coli
# 14  Escherichia coli
# 15  Escherichia coli
# 16  Escherichia coli
# 17  Escherichia coli
# 18  Escherichia coli
# 19  Escherichia coli
# 20  Escherichia coli
# 21  Escherichia coli
# 22  Escherichia coli
# 23  Escherichia coli
# ...

# %%
# Part 3: Data Filtering
# Show only rows (genes) where carb_fit is greater than 0.5
print(bacteria_data[bacteria_data['carb_fit'] > 0.5])
# Out:
#           C1        C2 sample_id           species Isolation origin  \
# 0   7.895415  6.303232      A001  Escherichia coli            urine
# 1   2.833671  6.823800      A002  Escherichia coli            blood
# 3   5.030077  4.642758      A004  Escherichia coli            feces
# 7   6.423557  8.646023      A008  Escherichia coli            blood
# 8   3.903013  6.026175      A009  Escherichia coli            feces
# 11  2.120512  3.840546      A012  Escherichia coli           animal
# 12  5.605287  8.474524      A013  Escherichia coli           animal
# 13  8.125718  6.337743      A014  Escherichia coli           animal
# 14  5.373610  6.328361      A015  Escherichia coli            feces
# 15  7.538784  6.070635      A016  Escherichia coli            urine
# 16  2.329631  6.700236      A017  Escherichia coli           animal
# 17  5.642871  4.021120      A018  Escherichia coli            blood
# 18  4.623605  6.560728      A019  Escherichia coli            urine
# ...

# %%
# Part 4: Handling Missing Data
# Create a copy of bacteria_data as bacteria_data_missing
bacteria_data_missing = bacteria_data.copy()

# Count the number of missing values per row
print(bacteria_data_missing.isna().sum())

# Create a new version of the dataset where missing values are filled with 1
print(bacteria_data_missing.fillna(1))

# Create another version where columns containing missing values are dropped entirely
print(bacteria_data_missing.dropna())
# Out:
# C1                  0
# C2                  0
# sample_id           0
# species             0
# Isolation origin    0
# Phenotype           0
# BSL                 0
# soln                3
# carb_fit            0
# cipro_fit           0
# genta_fit           0
# kan_fit             0
# pip_fit             0
# labels              0
# dtype: int64
#           C1        C2 sample_id           species Isolation origin  \
# 0   7.895415  6.303232      A001  Escherichia coli            urine
# 1   2.833671  6.823800      A002  Escherichia coli            blood
# 2   3.178256  5.519982      A003  Escherichia coli            blood
# 3   5.030077  4.642758      A004  Escherichia coli            feces
# 4   2.691040  4.057780      A005  Escherichia coli            feces
# 5   8.601402  5.937885      A006  Escherichia coli            blood
# 6   7.017246  8.315863      A007  Escherichia coli            feces
# 7   6.423557  8.646023      A008  Escherichia coli            blood
# ...

# %%
# Part 5: Checking Missing Data in Main Dataset
# Check whether missing values exist
print(bacteria_data_missing.isna().sum())

# If yes, report how many missing values are present (total or per column)
print(bacteria_data_missing.isna().sum().sum())
# Out:
# C1                  0
# C2                  0
# sample_id           0
# species             0
# Isolation origin    0
# Phenotype           0
# BSL                 0
# soln                3
# carb_fit            0
# cipro_fit           0
# genta_fit           0
# kan_fit             0
# pip_fit             0
# labels              0
# dtype: int64
# 3

# %%
# Part 6: Column Renaming
# Rename C1 to UMAP1
bacteria_data.rename(columns={'C1': 'UMAP1'}, inplace=True)

# Rename C2 to UMAP2
bacteria_data.rename(columns={'C2': 'UMAP2'}, inplace=True)

# Confirm as DataFrame
print(bacteria_data.head())
# Out:
#       UMAP1     UMAP2 sample_id           species Isolation origin  \
# 0  7.895415  6.303232      A001  Escherichia coli            urine
# 1  2.833671  6.823800      A002  Escherichia coli            blood
# 2  3.178256  5.519982      A003  Escherichia coli            blood
# 3  5.030077  4.642758      A004  Escherichia coli            feces
# 4  2.691040  4.057780      A005  Escherichia coli            feces
#
#            Phenotype  BSL      soln  carb_fit  cipro_fit  genta_fit   kan_fit  \
# 0  Pathogenic strain    2  0.043922  0.833539   0.040470   0.429654  0.046829
# 1  Pathogenic strain    2  0.098481  0.964883   0.110471   0.233285  0.000000
# 2   Commensal strain    1  0.066501  0.498872   0.061445   0.564547  0.313546
# 3  Pathogenic strain    2  0.116999  1.080682   0.101199   0.655379  0.305054
# 4   Commensal strain    1  0.101523  0.272807   0.120601   0.186437  0.121745
#
#     pip_fit  labels
# 0  0.857467       1
# 1  1.403835       6
# 2  0.368546       8
# ...

# %%
# Part 7: Sorting
# By the column BSL
print(bacteria_data.sort_values(by='BSL'))

# In descending order (highest to lowest)
print(bacteria_data.sort_values(by='BSL', ascending=False))
# Out:
#        UMAP1     UMAP2 sample_id           species Isolation origin  \
# 16  2.329631  6.700236      A017  Escherichia coli           animal
# 30  3.480180  5.646476      A031  Escherichia coli           animal
# 29  3.714443  5.799578      A030  Escherichia coli            blood
# 26  7.637985  6.490184      A027  Escherichia coli           animal
# 36  6.638712  5.152672      A037  Escherichia coli           animal
# 37  2.637517  4.127516      A038  Escherichia coli           animal
# 23  4.709624  4.452234      A024  Escherichia coli            blood
# 22  3.740108  4.893625      A023  Escherichia coli           animal
# 38  6.772678  7.540791      A039  Escherichia coli           animal
# 39  2.754321  5.394068      A040  Escherichia coli           animal
# 40  7.452787  6.422853      A041  Escherichia coli           animal
# 17  5.642871  4.021120      A018  Escherichia coli            blood
# 31  5.257375  5.715269      A032  Escherichia coli            blood
# ...

# %%
# Part 8: Groups Analysis
# the mean of cipro_fit grouped by label type
print(bacteria_data.groupby('labels')[['cipro_fit']].mean())

# the mean of carb_fit grouped by label type
print(bacteria_data.groupby('labels')[['carb_fit']].mean())

# the maximum of cipro_fit grouped by label type
print(bacteria_data.groupby('labels')[['cipro_fit']].max())

# the maximum of carb_fit grouped by label type
print(bacteria_data.groupby('labels')[['carb_fit']].max())

# Count how many rows belong to each Phenotype
print(bacteria_data['Phenotype'].value_counts())
# Out:
#         cipro_fit
# labels
# 0        0.064613
# 1        0.063612
# 2        0.267962
# 3        0.115426
# 4        0.325721
# 5        0.084008
# 6        0.058488
# 7        0.083757
# 8        0.060028
# 9        0.044911
#         carb_fit
# labels
# 0       1.083064
# 1       0.953535
# 2       0.831434
# 3       0.719393
# 4       0.988490
# 5       0.788392
# 6       0.684514
# 7       0.922803
# 8       0.453554
# 9       0.736483
#         cipro_fit
# labels
# 0        0.105668
# 1        0.098314
# 2        1.119326
# 3        0.164683
# 4        0.852120
# 5        0.095053
# 6        0.110910
# 7        0.174638
# 8        0.077279
# 9        0.091277
#         carb_fit
# labels
# 0       1.466022
# 1       1.442216
# 2       1.327152
# 3       1.395184
# 4       1.099966
# 5       1.166485
# 6       1.289325
# 7       1.514931
# 8       0.498872
# 9       1.370487
# Phenotype
# Commensal strain     32
# Pathogenic strain    18
# Name: count, dtype: int64
